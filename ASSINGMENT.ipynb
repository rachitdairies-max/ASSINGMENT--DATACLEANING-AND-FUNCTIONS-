# %% [markdown]
# #ASSINGMENT
#
#  1. What is data cleaning, and why is it important in data analysis?  What are the potential consequences of analyzing unclean or messy data? Explain the common steps involved in cleaning and organizing data.
#    - DATA Cleaning means checking and fixing data so it becomes correct , complete , and useful for analysis because if the data is incorrect or not cleaned well so the analysis will also be wrong .
#    - The potential consequences of analyzing unclean or messy data will lead us to wrong decisions , financial loss, and poor business planning . As if there is any wrong entry or duplicate entry so the report will turn into wrong report and it will create a bad decision related to firm.
#    - The Steps involved in cleaning and organizing data are
#       1- Remove Duplicate
#       removing duplicates will solve half of the problems as there won't be any duplicate entry .
#       2- Fill Blank Cells
#       If there is any blank cell left over then we have to cover all the blank boxes that are inside the data and if it is not useful so we can reove that blank .
#       3- Sort and Filter
#       Arrrange data properly and finding important values by highlighting it .
#
# 2. How would you sort the following dataset first by "Department" (A-Z) and then by "Salary" (Largest to
# Smallest)? Write a step-by-step approach.
# -  Steps to be followed in excel worksheet
#    1- Select the whole table including "employee" , "department" , 'salary"
#    2- Go to [ DATA ] IN EXCEL
#    3- GO TO SORT AND UNDER SORT BY SELECT  [ DEPARTMENT ] , UNDER ODER, SELECT [ A TO Z ]
#    4- CLICL ON - ADD LEVEL
#    5- A NEW LEVEL WILL GET ADDED IN THIS, UNDERY THEN BY , CHOOSE [ SALARY ] , UNDERY ORDER BY, SELECT [ LARGEST TO SMALLEST]
#    6 - CLICK OK
#
# 3. Eplain the use of text functions such as TRIM , LEFT, RIGHT, MID, and CONCAT in data cleaning.
#      - TRIM - It helps to remove extra spaces  betweeen texts and leaves ony spingle space between words , sentences. For ex- "  SHIVAM JHA   " AFTER TRIM - "SHIVAM JHA"
#      - LEFT - LEFT Functions return the specific number of characters from the beginnimg of a text . ex- = LEFT("SHIVAM2504",6)
#      SO THE RESULT WILL BE - "SHIVAM"
#      - RIGHT - It used to return the specific number of characters from the end  (right side). Ex- ("SHIVA2504",4) , The Result will be- "2504"
#      - MID - It used to return characters from the middle of the texts , ex- MID("SHIVAM2504",4,4) , The result will be - "VAM2"
#      - CONCAT - It used to combine texts from diffferent cells into one , Ex- First name = SHIVAM ; LAST NAME  = JHA
#          =CONCAT(A1," ",B1) - "SHIVAM JHA"
#
#   4. What is the role of date functions like TODAY in managing datasets?
#      - The TODAY() Functions helps us to return the current date automatically and updates every single day when we'll open the file , EX- =TODAY() - [ SHOWS TODAY DATE ] , [26 APR 2026].
#
#   5. Apply Data Validation to restrict Quantity values to only whole numbers between 1 and 10.
#   Configure an input message that appears when a user selects a cell in the "Quantity" column explaining:
# "Please enter a whole number between 1 and 10."
# Set up an error alert message that triggers if the user enters a number less than 1 or greater than 10,
# showing:
# "Invalid input! The quantity must be a whole number between 1 and 10.
#      - Select the "QUANTITY" Column , highlight the cells where we want to apply "DATA VALIDATION"
#      - Cllick on "DATA" - DATA VALIDATION
#      - Set Validatoin Rules , - Allow - whole number ; - DATA- Between [ MIN -1 , MAX -10 ]
#      This will restrict users to enter only whole numbers between 1 to 10.
#      - Open Input Message TAB and Enter
#      Tile - Quantity Entry
#      INPUT MESSAGE - Please Enter a whole number between 1 to 10
#      This message wil always appear when any user selects a cell.
#      - Open the ERROR Alert Tab and ENTER
#       STYLE : STOP
#       TITLE : INVALID INPUT
#       ERROR MESSAGE : Invalid Input! The quantity must be a whole number between 1 and 10
#       This message will appear whenever any user will try to enter a value less than 1 and greater than 10.
#
#   6.  Understand and apply fundamental text functions like LEFT, RIGHT, MID, and LEN.
#
# Extract the first 5 characters from the string "ExcelTipsAreGreat" using the LEFT function.
#
# Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
#
# Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
#
# Count the total number of characters in the string "Hello World!" using the LEN function.
#
# Create a formula to extract the middle 6 characters from "12345-67890-ABCDE".
#   - [ A ] - =LEFT("ExcelTipsAreGreat")
#            = Result : EXCEL
#   - [ B ] - =RIGHT("DataAbalysis.xlsx")
#            = Result : xlsx
#   - [ C ] - =MID("ExcelTipsAreGreat",6,4)
#             = Result : Tips
#   - [ D ] - =len("Hello World!")
#             = 12
#   - [ E ] - =MID("12345-67890-ABCDE",7,6)
#             = 67890
#
#  7. Understand how to combine text using CONCAT, TEXTJOIN, and the & operator.
#
# Use CONCAT to combine "Hello" and "World" with a space in between.
#
# Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN.
#
# Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "Excel
# Functions".
#
# Create a comma-separated list from the range A1:A5 using TEXTJOIN
#
# Combine first names in column A with last names in column B to create full names in column C.
#   - =CONCAT("Hello"," ","World")
#      - Result - Hello World
#   - =TEXTJOIN(", ",TRUE,"Apple","Banana","Cherry")
#      - Result - Apple , Banana, Cherry
#   - ="2025"&": "&"Excel Functions"
#      - Result - 2025: Excel Functions
#   - =TEXTJOIN(", ",TRUE,A1:A5)
#      - Result - If A1:A5 Contains Red, Blue, Green, Yellow, Black
#      - Red, Blue, Green, Yellow, Black
#   - =CONCAT(A1," ",B1)
#     - Result - If A1= John B1 = Doe
#                   C1 = John Doe
# 8. Understanding TODAY() and NOW()
#
#  a. What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use
#  each function.
#
#  b. If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are
#
#  left until that date
#
#  c. Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY
#
#  HH:MM AM/PM. ́
#
#  d. If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain
#
#  e. You want to store a static date (today’s date) in a cell without it changing every day. What keyboard shortcut should you use?
#   - [ A ] - =TODAY() returns only the current date.
#             =TODAY() - 04/26/2026
#           - =NOW() - 04/26/2026 01:15 PM
#   - [ B } - =A1-TODAY()
#           - 320
#   - [ C ] - =TEXT(NOW(),"MM/DD/YYYY HH:MM AM/PM")
#           -04/26/2026 01:15PM
#   - [ D ]- IF A CELL CONTAINS THIS FORMULA =TODAY() , Excel will automatically update it to the new current date when the worksheet will get open the next day It dosen't stay fixed
#   - [ E ] - PRESS - CTRL + ;
